# %%
# 📌 1_data_cleaning.ipynb - Data Loading and Preprocessing

import pandas as pd
import numpy as np

# Load the raw dataset
data = pd.read_csv('data/Motor_Vehicle_Collisions_with_KSI_Data_4326.csv')

# Replace common 'None'-like patterns with actual NaN values
data.replace(['None', 'none', 'NONE', '', ' ', 'nan', 'NaN'], np.nan, inplace=True)
data
# Out:
#          _id        ACCNUM        DATE  TIME       STREET1       STREET2  \
# 0          1  8.931840e+05  2006-01-01   236  WOODBINE AVE   O CONNOR DR
# 1          2  8.931840e+05  2006-01-01   236  WOODBINE AVE   O CONNOR DR
# 2          3  8.931840e+05  2006-01-01   236  WOODBINE AVE   O CONNOR DR
# 3          4  8.931840e+05  2006-01-01   236  WOODBINE AVE   O CONNOR DR
# 4          5  8.931840e+05  2006-01-01   236  WOODBINE AVE   O CONNOR DR
# ...      ...           ...         ...   ...           ...           ...
# 18952  18953  3.002957e+09  2023-12-26  2008    MCCOWAN RD  ELLESMERE RD
# 18953  18954  3.002971e+09  2023-12-28  1911   DUFFERIN ST     FISHER ST
# 18954  18955  3.002971e+09  2023-12-28  1911   DUFFERIN ST     FISHER ST
# 18955  18956  3.002978e+09  2023-12-29  1829    DONSIDE DR  MAYBOURNE AV
# 18956  18957  3.002978e+09  2023-12-29  1829    DONSIDE DR  MAYBOURNE AV
#
#       OFFSET      ROAD_CLASS               DISTRICT                ACCLOC  \
# 0        NaN  Major Arterial  Toronto and East York  Intersection Related
# 1        NaN  Major Arterial  Toronto and East York  Intersection Related
# 2        NaN  Major Arterial  Toronto and East York  Intersection Related
# 3        NaN  Major Arterial  Toronto and East York  Intersection Related
# 4        NaN  Major Arterial  Toronto and East York  Intersection Related
# ...      ...             ...                    ...                   ...
# 18952    NaN  Major Arterial                    NaN  Intersection Related
# 18953    NaN  Minor Arterial  Toronto and East York  Intersection Related
# 18954    NaN  Minor Arterial  Toronto and East York  Intersection Related
# 18955    NaN           Local            Scarborough  Intersection Related
# 18956    NaN           Local            Scarborough  Intersection Related
#
#        ... AG_DRIV REDLIGHT ALCOHOL DISABILITY HOOD_158    NEIGHBOURHOOD_158  \
# 0      ...     Yes      NaN     Yes        NaN       60     Woodbine-Lumsden
# 1      ...     Yes      NaN     Yes        NaN       60     Woodbine-Lumsden
# 2      ...     Yes      NaN     Yes        NaN       60     Woodbine-Lumsden
# 3      ...     Yes      NaN     Yes        NaN       60     Woodbine-Lumsden
# 4      ...     Yes      NaN     Yes        NaN       60     Woodbine-Lumsden
# ...    ...     ...      ...     ...        ...      ...                  ...
# 18952  ...     Yes      NaN     NaN        NaN      142         Woburn North
# 18953  ...     NaN      NaN     NaN        NaN       84      Little Portugal
# 18954  ...     NaN      NaN     NaN        NaN       84      Little Portugal
# 18955  ...     NaN      NaN     NaN        NaN      120  Clairlea-Birchmount
# 18956  ...     NaN      NaN     NaN        NaN      120  Clairlea-Birchmount
#
#       HOOD_140          NEIGHBOURHOOD_140 DIVISION  \
# 0           60      Woodbine-Lumsden (60)      D55
# 1           60      Woodbine-Lumsden (60)      D55
# 2           60      Woodbine-Lumsden (60)      D55
# 3           60      Woodbine-Lumsden (60)      D55
# 4           60      Woodbine-Lumsden (60)      D55
# ...        ...                        ...      ...
# 18952      137               Woburn (137)      D43
# 18953       84       Little Portugal (84)      D14
# 18954       84       Little Portugal (84)      D14
# 18955      120  Clairlea-Birchmount (120)      D41
# 18956      120  Clairlea-Birchmount (120)      D41
#
#                                                 geometry
# 0      {'type': 'MultiPoint', 'coordinates': [[-79.31...
# 1      {'type': 'MultiPoint', 'coordinates': [[-79.31...
# 2      {'type': 'MultiPoint', 'coordinates': [[-79.31...
# 3      {'type': 'MultiPoint', 'coordinates': [[-79.31...
# 4      {'type': 'MultiPoint', 'coordinates': [[-79.31...
# ...                                                  ...
# 18952  {'type': 'MultiPoint', 'coordinates': [[-79.25...
# 18953  {'type': 'MultiPoint', 'coordinates': [[-79.43...
# 18954  {'type': 'MultiPoint', 'coordinates': [[-79.43...
# 18955  {'type': 'MultiPoint', 'coordinates': [[-79.29...
# 18956  {'type': 'MultiPoint', 'coordinates': [[-79.29...
#
# [18957 rows x 50 columns]

# %%
# Remove columns with more than 70% missing values
missing_threshold = 0.7
missing_percent = data.isnull().mean()
columns_to_remove = missing_percent[missing_percent > missing_threshold].index.tolist()

print(f"Columns with >70% missing values: {columns_to_remove}")
data.drop(columns=columns_to_remove, inplace=True)
# Out:
# Columns with >70% missing values: ['OFFSET', 'FATAL_NO', 'PEDTYPE', 'PEDACT', 'PEDCOND', 'CYCLISTYPE', 'CYCACT', 'CYCCOND', 'CYCLIST', 'MOTORCYCLE', 'TRUCK', 'TRSN_CITY_VEH', 'EMERG_VEH', 'SPEEDING', 'REDLIGHT', 'ALCOHOL', 'DISABILITY']

# %%
# Remove irrelevant columns
irrelevant_columns = [
    '_id', 'ACCNUM', 'DATE', 'TIME', 'STREET1', 'STREET2', 'OFFSET',
    'HOOD_158', 'NEIGHBOURHOOD_158', 'HOOD_140', 'NEIGHBOURHOOD_140', 'geometry'
]
data.drop(columns=[col for col in irrelevant_columns if col in data.columns], inplace=True)

# %%
data.head()
# Out:
#        ROAD_CLASS               DISTRICT                ACCLOC    TRAFFCTL  \
# 0  Major Arterial  Toronto and East York  Intersection Related  No Control
# 1  Major Arterial  Toronto and East York  Intersection Related  No Control
# 2  Major Arterial  Toronto and East York  Intersection Related  No Control
# 3  Major Arterial  Toronto and East York  Intersection Related  No Control
# 4  Major Arterial  Toronto and East York  Intersection Related  No Control
#
#   VISIBILITY LIGHT RDSFCOND           ACCLASS    IMPACTYPE    INVTYPE  ...  \
# 0      Clear  Dark      Wet  Non-Fatal Injury  Approaching  Passenger  ...
# 1      Clear  Dark      Wet  Non-Fatal Injury  Approaching  Passenger  ...
# 2      Clear  Dark      Wet  Non-Fatal Injury  Approaching     Driver  ...
# 3      Clear  Dark      Wet  Non-Fatal Injury  Approaching  Passenger  ...
# 4      Clear  Dark      Wet  Non-Fatal Injury  Approaching  Passenger  ...
#
#   INITDIR                    VEHTYPE    MANOEUVER           DRIVACT DRIVCOND  \
# 0     NaN                        NaN          NaN               NaN      NaN
# 1     NaN                        NaN          NaN               NaN      NaN
# 2   North  Automobile, Station Wagon  Going Ahead  Driving Properly   Normal
# 3     NaN                        NaN          NaN               NaN      NaN
# 4     NaN                        NaN          NaN               NaN      NaN
#
#   PEDESTRIAN AUTOMOBILE PASSENGER AG_DRIV DIVISION
# 0        NaN        Yes       Yes     Yes      D55
# 1        NaN        Yes       Yes     Yes      D55
# 2        NaN        Yes       Yes     Yes      D55
# 3        NaN        Yes       Yes     Yes      D55
# 4        NaN        Yes       Yes     Yes      D55
#
# [5 rows x 22 columns]

# %%
# Drop binary columns with no variation if necessary
binary_columns = ['PEDESTRIAN', 'AUTOMOBILE', 'PASSENGER', 'AG_DRIV']
for col in binary_columns:
    if col in data.columns and data[col].nunique() <= 1:
        data.drop(columns=col, inplace=True)

# %%
data
# Out:
#            ROAD_CLASS               DISTRICT                ACCLOC  \
# 0      Major Arterial  Toronto and East York  Intersection Related
# 1      Major Arterial  Toronto and East York  Intersection Related
# 2      Major Arterial  Toronto and East York  Intersection Related
# 3      Major Arterial  Toronto and East York  Intersection Related
# 4      Major Arterial  Toronto and East York  Intersection Related
# ...               ...                    ...                   ...
# 18952  Major Arterial                    NaN  Intersection Related
# 18953  Minor Arterial  Toronto and East York  Intersection Related
# 18954  Minor Arterial  Toronto and East York  Intersection Related
# 18955           Local            Scarborough  Intersection Related
# 18956           Local            Scarborough  Intersection Related
#
#              TRAFFCTL              VISIBILITY             LIGHT RDSFCOND  \
# 0          No Control                   Clear              Dark      Wet
# 1          No Control                   Clear              Dark      Wet
# 2          No Control                   Clear              Dark      Wet
# 3          No Control                   Clear              Dark      Wet
# 4          No Control                   Clear              Dark      Wet
# ...               ...                     ...               ...      ...
# 18952  Traffic Signal  Fog, Mist, Smoke, Dust  Dark, artificial      Wet
# 18953      No Control                    Rain              Dark      Wet
# 18954      No Control                    Rain              Dark      Wet
# 18955      No Control                    Rain              Dark      Wet
# 18956      No Control                    Rain              Dark      Wet
#
#                 ACCLASS              IMPACTYPE     INVTYPE    INVAGE INJURY  \
# 0      Non-Fatal Injury            Approaching   Passenger  50 to 54  Major
# 1      Non-Fatal Injury            Approaching   Passenger  15 to 19  Minor
# 2      Non-Fatal Injury            Approaching      Driver  55 to 59  Minor
# 3      Non-Fatal Injury            Approaching   Passenger  20 to 24  Minor
# 4      Non-Fatal Injury            Approaching   Passenger  15 to 19  Minor
# ...                 ...                    ...         ...       ...    ...
# 18952  Non-Fatal Injury  Pedestrian Collisions  Pedestrian  20 to 24  Major
# 18953             Fatal  Pedestrian Collisions  Pedestrian  80 to 84  Fatal
# 18954             Fatal  Pedestrian Collisions      Driver  20 to 24    NaN
# 18955  Non-Fatal Injury  Pedestrian Collisions      Driver  65 to 69    NaN
# 18956  Non-Fatal Injury  Pedestrian Collisions  Pedestrian  15 to 19  Major
#
#       INITDIR                    VEHTYPE    MANOEUVER           DRIVACT  \
# 0         NaN                        NaN          NaN               NaN
# 1         NaN                        NaN          NaN               NaN
# 2       North  Automobile, Station Wagon  Going Ahead  Driving Properly
# 3         NaN                        NaN          NaN               NaN
# 4         NaN                        NaN          NaN               NaN
# ...       ...                        ...          ...               ...
# 18952     NaN                        NaN          NaN               NaN
# 18953    East                        NaN          NaN               NaN
# 18954   North  Automobile, Station Wagon  Going Ahead  Driving Properly
# 18955    West  Automobile, Station Wagon  Going Ahead  Driving Properly
# 18956     NaN                        NaN          NaN               NaN
#
#       DRIVCOND DIVISION
# 0          NaN      D55
# 1          NaN      D55
# 2       Normal      D55
# 3          NaN      D55
# 4          NaN      D55
# ...        ...      ...
# 18952      NaN      D43
# 18953      NaN      D14
# 18954   Normal      D14
# 18955   Normal      D41
# 18956      NaN      D41
#
# [18957 rows x 18 columns]

# %%
# Fill remaining missing values
for col in data.columns:
    if data[col].dtype == 'object':
        data[col].fillna(data[col].mode()[0], inplace=True)
    else:
        data[col].fillna(data[col].median(), inplace=True)
# Out:
# C:\Users\mulla\AppData\Local\Temp\ipykernel_110200\856095354.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[col].fillna(data[col].mode()[0], inplace=True)

# %%
# Final check
print("Final dataset shape:", data.shape)
print("Missing values per column:\n", data.isnull().sum())
print("Unique INJURY classes:", data['INJURY'].unique())
# Out:
# Final dataset shape: (18957, 18)
# Missing values per column:
#  ROAD_CLASS    0
# DISTRICT      0
# ACCLOC        0
# TRAFFCTL      0
# VISIBILITY    0
# LIGHT         0
# RDSFCOND      0
# ACCLASS       0
# IMPACTYPE     0
# INVTYPE       0
# INVAGE        0
# INJURY        0
# INITDIR       0
# VEHTYPE       0
# MANOEUVER     0
# DRIVACT       0
# DRIVCOND      0
# DIVISION      0
# dtype: int64
# Unique INJURY classes: ['Major' 'Minor' 'Fatal' 'Minimal']

# %%
# Save cleaned data (without encoding)
data.to_csv('data/cleaned_data.csv', index=False)

# %%
# correaltion metrix
